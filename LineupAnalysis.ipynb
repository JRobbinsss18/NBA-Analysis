# %%
from itertools import combinations
from nba_api.stats.endpoints import commonteamroster, teamdashlineups
from nba_api.stats.static import teams
import pandas as pd
import time

# %%
def get_team_roster(team_name: str, season: str):
    nba_teams = teams.get_teams()
    team = next((team for team in nba_teams if team['full_name'].lower() == team_name.lower()), None)
    if not team:
        raise ValueError(f"Team '{team_name}' not found.")
    
    team_id = team['id']
    roster_data = commonteamroster.CommonTeamRoster(team_id=team_id, season=season)
    roster = roster_data.get_normalized_dict()
    roster_df = pd.DataFrame(roster['CommonTeamRoster'])
    return roster_df

# %%
def normalize_player_name(player_name):

    parts = player_name.split()
    if len(parts) > 1:
        return f"{parts[0][0]}. {' '.join(parts[1:])}"
    return player_name

# %%
def exponential_backoff_retry(func, *args, max_retries=5, initial_wait=1, multiplier=2, **kwargs):
    wait_time = initial_wait
    for attempt in range(max_retries):
        try:
            return func(*args, **kwargs)
        except Exception as e:
            if attempt < max_retries - 1:
                print(f"Error: {e}. Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
                wait_time *= multiplier
            else:
                raise e

# %%
def analyze_lineups(players, teamdashlineups, team_id, opponent_team_id):

    retries = 5
    backoff = 1
    while retries > 0:
        try:
            lineups_df = exponential_backoff_retry(
                teamdashlineups.TeamDashLineups,
                team_id=team_id,
                opponent_team_id=opponent_team_id
            ).get_data_frames()[1]
            break
        except Exception as e:
            print(f"Error fetching lineup data: {e}. Retrying in {backoff} seconds...")
            time.sleep(backoff)
            backoff *= 2
            retries -= 1

    if retries == 0:
        print("Failed to fetch lineup data after multiple retries.")
        return None

    normalized_players = [normalize_player_name(player) for player in players]

    with_players = lineups_df[
        lineups_df["GROUP_NAME"].apply(lambda x: all(player in x for player in normalized_players))
    ]

    without_players = lineups_df[
        ~lineups_df["GROUP_NAME"].apply(lambda x: all(player in x for player in normalized_players))
    ]

    total_minutes_with = with_players["MIN"].sum()
    total_plus_minus_with = with_players["PLUS_MINUS"].sum()
    
    total_minutes_without = without_players["MIN"].sum()
    total_plus_minus_without = without_players["PLUS_MINUS"].sum()

    print("Lineups with players:")
    print(f"  Total Minutes: {total_minutes_with}")
    print(f"  Total Plus-Minus: {total_plus_minus_with}")

    print("\nLineups without players:")
    print(f"  Total Minutes: {total_minutes_without}")
    print(f"  Total Plus-Minus: {total_plus_minus_without}")

    return {
        "with_players": {
            "total_minutes": total_minutes_with,
            "total_plus_minus": total_plus_minus_with,
            "lineup_count": len(with_players)
        },
        "without_players": {
            "total_minutes": total_minutes_without,
            "total_plus_minus": total_plus_minus_without,
            "lineup_count": len(without_players)
        }
    }

# %%
players = ["B Podziemski", "Draymond Green"]
data = analyze_lineups(players, teamdashlineups, team_id = 1610612744, opponent_team_id = 1610612738)
# Out:
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0

# %%
warriors_roster = get_team_roster("golden state warriors", "2024-25")
player_names = warriors_roster['PLAYER'].tolist()
player_names
# Out:
# ['Gary Payton II',
#  'Jonathan Kuminga',
#  'Kyle Anderson',
#  'Brandin Podziemski',
#  'Moses Moody',
#  'Kevon Looney',
#  'Buddy Hield',
#  'Gui Santos',
#  'Quinten Post',
#  'Andrew Wiggins',
#  'Draymond Green',
#  'Stephen Curry',
#  'Trayce Jackson-Davis',
#  'Lindy Waters III',
#  'Pat Spencer',
#  'Dennis Schröder']

# %%
categories = {"Duo": 2, "Trio": 3, "Quartet": 4, "Quintet": 5}
top_results = {}

for category, size in categories.items():
    print(f"\nAnalyzing {category}s:")
    combinations_list = list(combinations(player_names, size))
    results = []
    
    for combo in combinations_list:
        time.sleep(0.5)
        print(f"Analyzing {category}: {combo}")
        result = analyze_lineups(
            players=list(combo),
            teamdashlineups=teamdashlineups,
            team_id=1610612744,  # Warriors team ID
            opponent_team_id=1610612738  # Celtics team ID
        )
        if result:
            results.append({
                "group": combo,
                "plus_minus_with": result["with_players"]["total_plus_minus"],
                "minutes_with": result["with_players"]["total_minutes"]
            })

    sorted_results = sorted(results, key=lambda x: x["plus_minus_with"], reverse=True)[:5]
    top_results[category] = sorted_results

for category, results in top_results.items():
    print(f"\nTop 5 {category}s by +/-:")
    for entry in results:
        print(f"{category}: {entry['group']}, +/-: {entry['plus_minus_with']}, Minutes: {entry['minutes_with']}")
# Out:
# Analyzing Duos:
# Analyzing Duo: ('Gary Payton II', 'Jonathan Kuminga')
# Lineups with players:
#   Total Minutes: 2.8833333333333333
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 45.11666666666667
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Gary Payton II', 'Kyle Anderson')
# Lineups with players:
#   Total Minutes: 4.74
#   Total Plus-Minus: -2.0
#
# Lineups without players:
#   Total Minutes: 43.260000000000005
#   Total Plus-Minus: 8.0
# Analyzing Duo: ('Gary Payton II', 'Brandin Podziemski')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gary Payton II', 'Moses Moody')
# Lineups with players:
#   Total Minutes: 2.5166666666666666
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 45.483333333333334
#   Total Plus-Minus: 0.0
# Analyzing Duo: ('Gary Payton II', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 7.121666666666666
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 40.87833333333333
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Gary Payton II', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 9.799999999999999
#   Total Plus-Minus: 5.0
#
# Lineups without players:
#   Total Minutes: 38.2
#   Total Plus-Minus: 1.0
# Analyzing Duo: ('Gary Payton II', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gary Payton II', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gary Payton II', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 15.428333333333333
#   Total Plus-Minus: 8.0
#
# Lineups without players:
#   Total Minutes: 32.57166666666667
#   Total Plus-Minus: -2.0
# Analyzing Duo: ('Gary Payton II', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 12.445
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 35.555
#   Total Plus-Minus: 0.0
# Analyzing Duo: ('Gary Payton II', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 18.311666666666667
#   Total Plus-Minus: 7.0
#
# Lineups without players:
#   Total Minutes: 29.688333333333333
#   Total Plus-Minus: -1.0
# Analyzing Duo: ('Gary Payton II', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gary Payton II', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gary Payton II', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gary Payton II', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Jonathan Kuminga', 'Kyle Anderson')
# Lineups with players:
#   Total Minutes: 15.066666666666666
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 32.93333333333334
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Jonathan Kuminga', 'Brandin Podziemski')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Jonathan Kuminga', 'Moses Moody')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Jonathan Kuminga', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 8.015
#   Total Plus-Minus: -6.0
#
# Lineups without players:
#   Total Minutes: 39.985
#   Total Plus-Minus: 12.0
# Analyzing Duo: ('Jonathan Kuminga', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 16.783333333333335
#   Total Plus-Minus: -2.0
#
# Lineups without players:
#   Total Minutes: 31.21666666666667
#   Total Plus-Minus: 8.0
# Analyzing Duo: ('Jonathan Kuminga', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Jonathan Kuminga', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Jonathan Kuminga', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 1.1666666666666667
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 46.83333333333334
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Jonathan Kuminga', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 3.25
#   Total Plus-Minus: -3.0
#
# Lineups without players:
#   Total Minutes: 44.75
#   Total Plus-Minus: 9.0
# Analyzing Duo: ('Jonathan Kuminga', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 4.335
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 43.665000000000006
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Jonathan Kuminga', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 6.4
#   Total Plus-Minus: 7.0
#
# Lineups without players:
#   Total Minutes: 41.599999999999994
#   Total Plus-Minus: -1.0
# Analyzing Duo: ('Jonathan Kuminga', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 13.9
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 34.099999999999994
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Jonathan Kuminga', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Jonathan Kuminga', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kyle Anderson', 'Brandin Podziemski')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kyle Anderson', 'Moses Moody')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kyle Anderson', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 7.881666666666667
#   Total Plus-Minus: -3.0
#
# Lineups without players:
#   Total Minutes: 40.11833333333333
#   Total Plus-Minus: 9.0
# Analyzing Duo: ('Kyle Anderson', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 13.981666666666667
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 34.01833333333333
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kyle Anderson', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kyle Anderson', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kyle Anderson', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 5.988333333333333
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 42.01166666666667
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Kyle Anderson', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 5.321666666666667
#   Total Plus-Minus: -6.0
#
# Lineups without players:
#   Total Minutes: 42.67833333333334
#   Total Plus-Minus: 12.0
# Analyzing Duo: ('Kyle Anderson', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 6.273333333333333
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 41.72666666666667
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Kyle Anderson', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 6.4
#   Total Plus-Minus: 7.0
#
# Lineups without players:
#   Total Minutes: 41.599999999999994
#   Total Plus-Minus: -1.0
# Analyzing Duo: ('Kyle Anderson', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 13.9
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 34.099999999999994
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Kyle Anderson', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kyle Anderson', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Moses Moody')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Brandin Podziemski', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Moses Moody', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Moses Moody', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 1.1333333333333333
#   Total Plus-Minus: 5.0
#
# Lineups without players:
#   Total Minutes: 46.866666666666674
#   Total Plus-Minus: 1.0
# Analyzing Duo: ('Moses Moody', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Moses Moody', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Moses Moody', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 13.433333333333334
#   Total Plus-Minus: -5.0
#
# Lineups without players:
#   Total Minutes: 34.56666666666667
#   Total Plus-Minus: 11.0
# Analyzing Duo: ('Moses Moody', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 13.433333333333334
#   Total Plus-Minus: -5.0
#
# Lineups without players:
#   Total Minutes: 34.56666666666667
#   Total Plus-Minus: 11.0
# Analyzing Duo: ('Moses Moody', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 13.433333333333334
#   Total Plus-Minus: -5.0
#
# Lineups without players:
#   Total Minutes: 34.56666666666667
#   Total Plus-Minus: 11.0
# Analyzing Duo: ('Moses Moody', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 9.783333333333333
#   Total Plus-Minus: -16.0
#
# Lineups without players:
#   Total Minutes: 38.21666666666667
#   Total Plus-Minus: 22.0
# Analyzing Duo: ('Moses Moody', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Moses Moody', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Moses Moody', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kevon Looney', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 11.871666666666666
#   Total Plus-Minus: 4.0
#
# Lineups without players:
#   Total Minutes: 36.12833333333333
#   Total Plus-Minus: 2.0
# Analyzing Duo: ('Kevon Looney', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kevon Looney', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kevon Looney', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 7.861666666666666
#   Total Plus-Minus: 10.0
#
# Lineups without players:
#   Total Minutes: 40.138333333333335
#   Total Plus-Minus: -4.0
# Analyzing Duo: ('Kevon Looney', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 4.878333333333334
#   Total Plus-Minus: 8.0
#
# Lineups without players:
#   Total Minutes: 43.12166666666667
#   Total Plus-Minus: -2.0
# Analyzing Duo: ('Kevon Looney', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 10.745
#   Total Plus-Minus: 9.0
#
# Lineups without players:
#   Total Minutes: 37.254999999999995
#   Total Plus-Minus: -3.0
# Analyzing Duo: ('Kevon Looney', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kevon Looney', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 5.131666666666667
#   Total Plus-Minus: -5.0
#
# Lineups without players:
#   Total Minutes: 42.86833333333333
#   Total Plus-Minus: 11.0
# Analyzing Duo: ('Kevon Looney', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Kevon Looney', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Buddy Hield', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Buddy Hield', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Buddy Hield', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 11.754999999999999
#   Total Plus-Minus: 22.0
#
# Lineups without players:
#   Total Minutes: 36.245000000000005
#   Total Plus-Minus: -16.0
# Analyzing Duo: ('Buddy Hield', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 14.771666666666667
#   Total Plus-Minus: 19.0
#
# Lineups without players:
#   Total Minutes: 33.22833333333334
#   Total Plus-Minus: -13.0
# Analyzing Duo: ('Buddy Hield', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 14.923333333333334
#   Total Plus-Minus: 21.0
#
# Lineups without players:
#   Total Minutes: 33.07666666666667
#   Total Plus-Minus: -15.0
# Analyzing Duo: ('Buddy Hield', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 5.233333333333333
#   Total Plus-Minus: 7.0
#
# Lineups without players:
#   Total Minutes: 42.766666666666666
#   Total Plus-Minus: -1.0
# Analyzing Duo: ('Buddy Hield', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 13.9
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 34.099999999999994
#   Total Plus-Minus: 7.0
# Analyzing Duo: ('Buddy Hield', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Buddy Hield', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gui Santos', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gui Santos', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gui Santos', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gui Santos', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gui Santos', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gui Santos', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gui Santos', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Gui Santos', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Quinten Post', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Quinten Post', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Quinten Post', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Quinten Post', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Quinten Post', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Quinten Post', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Quinten Post', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Andrew Wiggins', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 27.06666666666667
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 20.933333333333337
#   Total Plus-Minus: 0.0
# Analyzing Duo: ('Andrew Wiggins', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 31.216666666666672
#   Total Plus-Minus: 8.0
#
# Lineups without players:
#   Total Minutes: 16.783333333333335
#   Total Plus-Minus: -2.0
# Analyzing Duo: ('Andrew Wiggins', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 10.95
#   Total Plus-Minus: -16.0
#
# Lineups without players:
#   Total Minutes: 37.05
#   Total Plus-Minus: 22.0
# Analyzing Duo: ('Andrew Wiggins', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Andrew Wiggins', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Andrew Wiggins', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Draymond Green', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 27.06666666666667
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 20.933333333333337
#   Total Plus-Minus: 0.0
# Analyzing Duo: ('Draymond Green', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 9.783333333333333
#   Total Plus-Minus: -16.0
#
# Lineups without players:
#   Total Minutes: 38.21666666666667
#   Total Plus-Minus: 22.0
# Analyzing Duo: ('Draymond Green', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 3.25
#   Total Plus-Minus: -3.0
#
# Lineups without players:
#   Total Minutes: 44.75
#   Total Plus-Minus: 9.0
# Analyzing Duo: ('Draymond Green', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Draymond Green', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Stephen Curry', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 10.95
#   Total Plus-Minus: -16.0
#
# Lineups without players:
#   Total Minutes: 37.05
#   Total Plus-Minus: 22.0
# Analyzing Duo: ('Stephen Curry', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.285
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 47.715
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Stephen Curry', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Stephen Curry', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Trayce Jackson-Davis', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 5.233333333333333
#   Total Plus-Minus: 7.0
#
# Lineups without players:
#   Total Minutes: 42.766666666666666
#   Total Plus-Minus: -1.0
# Analyzing Duo: ('Trayce Jackson-Davis', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Trayce Jackson-Davis', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Duo: ('Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
#
# Analyzing Trios:
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Kyle Anderson')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Brandin Podziemski')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Moses Moody')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 2.8833333333333333
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 45.11666666666667
#   Total Plus-Minus: 7.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 2.8833333333333333
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 45.11666666666667
#   Total Plus-Minus: 7.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 2.8833333333333333
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 45.11666666666667
#   Total Plus-Minus: 7.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Jonathan Kuminga', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Brandin Podziemski')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Moses Moody')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 2.75
#   Total Plus-Minus: 2.0
#
# Lineups without players:
#   Total Minutes: 45.25
#   Total Plus-Minus: 4.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 4.74
#   Total Plus-Minus: -2.0
#
# Lineups without players:
#   Total Minutes: 43.260000000000005
#   Total Plus-Minus: 8.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 1.99
#   Total Plus-Minus: -4.0
#
# Lineups without players:
#   Total Minutes: 46.010000000000005
#   Total Plus-Minus: 10.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 4.74
#   Total Plus-Minus: -2.0
#
# Lineups without players:
#   Total Minutes: 43.260000000000005
#   Total Plus-Minus: 8.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kyle Anderson', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Moses Moody')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Brandin Podziemski', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Kevon Looney')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 2.5166666666666666
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 45.483333333333334
#   Total Plus-Minus: 0.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 2.5166666666666666
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 45.483333333333334
#   Total Plus-Minus: 0.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 2.5166666666666666
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 45.483333333333334
#   Total Plus-Minus: 0.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Moses Moody', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Buddy Hield')
# Lineups with players:
#   Total Minutes: 3.1166666666666667
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 44.88333333333333
#   Total Plus-Minus: 7.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 4.238333333333333
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 43.76166666666667
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 1.255
#   Total Plus-Minus: -2.0
#
# Lineups without players:
#   Total Minutes: 46.745000000000005
#   Total Plus-Minus: 8.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 7.121666666666666
#   Total Plus-Minus: -1.0
#
# Lineups without players:
#   Total Minutes: 40.87833333333333
#   Total Plus-Minus: 7.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Kevon Looney', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Gui Santos')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 6.916666666666667
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 41.08333333333333
#   Total Plus-Minus: 0.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 6.683333333333334
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 41.31666666666666
#   Total Plus-Minus: 0.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 9.799999999999999
#   Total Plus-Minus: 5.0
#
# Lineups without players:
#   Total Minutes: 38.2
#   Total Plus-Minus: 1.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Buddy Hield', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Gui Santos', 'Quinten Post')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Gui Santos', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Gui Santos', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Gui Santos', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Gui Santos', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Gui Santos', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Gui Santos', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Gui Santos', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Quinten Post', 'Andrew Wiggins')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Quinten Post', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Quinten Post', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Quinten Post', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Quinten Post', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Quinten Post', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Quinten Post', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Andrew Wiggins', 'Draymond Green')
# Lineups with players:
#   Total Minutes: 12.445
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 35.555
#   Total Plus-Minus: 0.0
# Analyzing Trio: ('Gary Payton II', 'Andrew Wiggins', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 15.428333333333333
#   Total Plus-Minus: 8.0
#
# Lineups without players:
#   Total Minutes: 32.57166666666667
#   Total Plus-Minus: -2.0
# Analyzing Trio: ('Gary Payton II', 'Andrew Wiggins', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Andrew Wiggins', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Andrew Wiggins', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Andrew Wiggins', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Draymond Green', 'Stephen Curry')
# Lineups with players:
#   Total Minutes: 12.445
#   Total Plus-Minus: 6.0
#
# Lineups without players:
#   Total Minutes: 35.555
#   Total Plus-Minus: 0.0
# Analyzing Trio: ('Gary Payton II', 'Draymond Green', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Draymond Green', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Draymond Green', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Draymond Green', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Stephen Curry', 'Trayce Jackson-Davis')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Stephen Curry', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Stephen Curry', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Stephen Curry', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Trayce Jackson-Davis', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Trayce Jackson-Davis', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Trayce Jackson-Davis', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Trio: ('Gary Payton II', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
# ...
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Draymond Green', 'Trayce Jackson-Davis', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Draymond Green', 'Trayce Jackson-Davis', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Draymond Green', 'Trayce Jackson-Davis', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Draymond Green', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Draymond Green', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Draymond Green', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Stephen Curry', 'Trayce Jackson-Davis', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Stephen Curry', 'Trayce Jackson-Davis', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Stephen Curry', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Stephen Curry', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Stephen Curry', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Trayce Jackson-Davis', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Andrew Wiggins', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Stephen Curry', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Stephen Curry', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Stephen Curry', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Trayce Jackson-Davis', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Draymond Green', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Stephen Curry', 'Trayce Jackson-Davis', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Stephen Curry', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Quinten Post', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Stephen Curry', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Stephen Curry', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Stephen Curry', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Trayce Jackson-Davis', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Draymond Green', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Stephen Curry', 'Trayce Jackson-Davis', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Stephen Curry', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Andrew Wiggins', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Draymond Green', 'Stephen Curry', 'Trayce Jackson-Davis', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Draymond Green', 'Stephen Curry', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Draymond Green', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
# Analyzing Quintet: ('Stephen Curry', 'Trayce Jackson-Davis', 'Lindy Waters III', 'Pat Spencer', 'Dennis Schröder')
# Lineups with players:
#   Total Minutes: 0.0
#   Total Plus-Minus: 0.0
#
# Lineups without players:
#   Total Minutes: 48.00000000000001
#   Total Plus-Minus: 6.0
#
# Top 5 Duos by +/-:
# Duo: ('Buddy Hield', 'Andrew Wiggins'), +/-: 22.0, Minutes: 11.754999999999999
# Duo: ('Buddy Hield', 'Stephen Curry'), +/-: 21.0, Minutes: 14.923333333333334
# Duo: ('Buddy Hield', 'Draymond Green'), +/-: 19.0, Minutes: 14.771666666666667
# Duo: ('Kevon Looney', 'Andrew Wiggins'), +/-: 10.0, Minutes: 7.861666666666666
# Duo: ('Kevon Looney', 'Stephen Curry'), +/-: 9.0, Minutes: 10.745
#
# Top 5 Trios by +/-:
# Trio: ('Buddy Hield', 'Andrew Wiggins', 'Draymond Green'), +/-: 22.0, Minutes: 11.521666666666667
# Trio: ('Buddy Hield', 'Andrew Wiggins', 'Stephen Curry'), +/-: 22.0, Minutes: 11.754999999999999
# Trio: ('Buddy Hield', 'Draymond Green', 'Stephen Curry'), +/-: 22.0, Minutes: 11.521666666666667
# Trio: ('Kevon Looney', 'Buddy Hield', 'Andrew Wiggins'), +/-: 10.0, Minutes: 3.856666666666667
# Trio: ('Kevon Looney', 'Buddy Hield', 'Draymond Green'), +/-: 10.0, Minutes: 3.6233333333333335
#
# Top 5 Quartets by +/-:
# Quartet: ('Buddy Hield', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 22.0, Minutes: 11.521666666666667
# Quartet: ('Kevon Looney', 'Buddy Hield', 'Andrew Wiggins', 'Draymond Green'), +/-: 10.0, Minutes: 3.6233333333333335
# Quartet: ('Kevon Looney', 'Buddy Hield', 'Andrew Wiggins', 'Stephen Curry'), +/-: 10.0, Minutes: 3.856666666666667
# Quartet: ('Kevon Looney', 'Buddy Hield', 'Draymond Green', 'Stephen Curry'), +/-: 10.0, Minutes: 3.6233333333333335
# Quartet: ('Kevon Looney', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 8.0, Minutes: 4.878333333333334
#
# Top 5 Quintets by +/-:
# Quintet: ('Kevon Looney', 'Buddy Hield', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 10.0, Minutes: 3.6233333333333335
# Quintet: ('Jonathan Kuminga', 'Kyle Anderson', 'Buddy Hield', 'Trayce Jackson-Davis', 'Lindy Waters III'), +/-: 7.0, Minutes: 5.233333333333333
# Quintet: ('Gary Payton II', 'Moses Moody', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 6.0, Minutes: 2.5166666666666666
# Quintet: ('Gary Payton II', 'Buddy Hield', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 6.0, Minutes: 6.683333333333334
# Quintet: ('Moses Moody', 'Buddy Hield', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 5.0, Minutes: 1.1333333333333333

# %%
for category, results in top_results.items():
    print(f"\nTop 5 {category}s by +/-:")
    for entry in results:
        print(f"{category}: {entry['group']}, +/-: {entry['plus_minus_with']}, Minutes: {entry['minutes_with']}")
# Out:
# Top 5 Duos by +/-:
# Duo: ('Buddy Hield', 'Andrew Wiggins'), +/-: 22.0, Minutes: 11.754999999999999
# Duo: ('Buddy Hield', 'Stephen Curry'), +/-: 21.0, Minutes: 14.923333333333334
# Duo: ('Buddy Hield', 'Draymond Green'), +/-: 19.0, Minutes: 14.771666666666667
# Duo: ('Kevon Looney', 'Andrew Wiggins'), +/-: 10.0, Minutes: 7.861666666666666
# Duo: ('Kevon Looney', 'Stephen Curry'), +/-: 9.0, Minutes: 10.745
#
# Top 5 Trios by +/-:
# Trio: ('Buddy Hield', 'Andrew Wiggins', 'Draymond Green'), +/-: 22.0, Minutes: 11.521666666666667
# Trio: ('Buddy Hield', 'Andrew Wiggins', 'Stephen Curry'), +/-: 22.0, Minutes: 11.754999999999999
# Trio: ('Buddy Hield', 'Draymond Green', 'Stephen Curry'), +/-: 22.0, Minutes: 11.521666666666667
# Trio: ('Kevon Looney', 'Buddy Hield', 'Andrew Wiggins'), +/-: 10.0, Minutes: 3.856666666666667
# Trio: ('Kevon Looney', 'Buddy Hield', 'Draymond Green'), +/-: 10.0, Minutes: 3.6233333333333335
#
# Top 5 Quartets by +/-:
# Quartet: ('Buddy Hield', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 22.0, Minutes: 11.521666666666667
# Quartet: ('Kevon Looney', 'Buddy Hield', 'Andrew Wiggins', 'Draymond Green'), +/-: 10.0, Minutes: 3.6233333333333335
# Quartet: ('Kevon Looney', 'Buddy Hield', 'Andrew Wiggins', 'Stephen Curry'), +/-: 10.0, Minutes: 3.856666666666667
# Quartet: ('Kevon Looney', 'Buddy Hield', 'Draymond Green', 'Stephen Curry'), +/-: 10.0, Minutes: 3.6233333333333335
# Quartet: ('Kevon Looney', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 8.0, Minutes: 4.878333333333334
#
# Top 5 Quintets by +/-:
# Quintet: ('Kevon Looney', 'Buddy Hield', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 10.0, Minutes: 3.6233333333333335
# Quintet: ('Jonathan Kuminga', 'Kyle Anderson', 'Buddy Hield', 'Trayce Jackson-Davis', 'Lindy Waters III'), +/-: 7.0, Minutes: 5.233333333333333
# Quintet: ('Gary Payton II', 'Moses Moody', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 6.0, Minutes: 2.5166666666666666
# Quintet: ('Gary Payton II', 'Buddy Hield', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 6.0, Minutes: 6.683333333333334
# Quintet: ('Moses Moody', 'Buddy Hield', 'Andrew Wiggins', 'Draymond Green', 'Stephen Curry'), +/-: 5.0, Minutes: 1.1333333333333333

# %% [markdown]
# # Takeaways
# ## Note: This code can be adapted to provide analytics for any specific team, it simply would just take a long time to run if i was to provide this analysis tool against every team, team specific insights also provides great feedback!
# - The most obvious
